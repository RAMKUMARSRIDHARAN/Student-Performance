# %%
#Importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore", category=UserWarning)
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
#loading Dataset
Student_Performance = pd.read_csv("D:\\DS with Py\\Data Science Datasets\\Student_Performance.csv")
Student_Performance
# Out:
#      Unnamed: 0 school sex  age address famsize Pstatus  Medu  Fedu      Mjob  \
# 0             0     GP   F   18       U     GT3       A     4     4   at_home
# 1             1     GP   F   17       U     GT3       T     1     1   at_home
# 2             2     GP   F   15       U     LE3       T     1     1   at_home
# 3             3     GP   F   15       U     GT3       T     4     2    health
# 4             4     GP   F   16       U     GT3       T     3     3     other
# ..          ...    ...  ..  ...     ...     ...     ...   ...   ...       ...
# 390         390     MS   M   20       U     LE3       A     2     2  services
# 391         391     MS   M   17       U     LE3       T     3     1  services
# 392         392     MS   M   21       R     GT3       T     1     1     other
# 393         393     MS   M   18       R     LE3       T     3     2  services
# 394         394     MS   M   19       U     LE3       T     1     1     other
#
# ...

# %%
Student_Performance.columns = Student_Performance.columns.str.strip()
Student_Data = Student_Performance.drop('Unnamed: 0', axis=1)
Student_Data
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
Student_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      395 non-null    object
#  1   sex         395 non-null    object
#  2   age         395 non-null    int64
#  3   address     395 non-null    object
#  4   famsize     395 non-null    object
#  5   Pstatus     395 non-null    object
#  6   Medu        395 non-null    int64
#  7   Fedu        395 non-null    int64
#  8   Mjob        395 non-null    object
#  9   Fjob        395 non-null    object
#  10  reason      395 non-null    object
#  11  guardian    395 non-null    object
#  12  traveltime  395 non-null    int64
#  13  studytime   395 non-null    int64
#  14  failures    395 non-null    int64
#  15  schoolsup   395 non-null    object
#  16  famsup      395 non-null    object
#  17  paid        395 non-null    object
#  18  activities  395 non-null    object
# ...

# %%
Student_Data.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean    16.696203    2.749367    2.521519    1.448101    2.035443    0.334177
# std      1.276043    1.094735    1.088201    0.697505    0.839240    0.743651
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    2.000000    1.000000    1.000000    0.000000
# 50%     17.000000    3.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean     3.944304    3.235443    3.108861    1.481013    2.291139    3.554430
# ...

# %%
Student_Data.isnull().sum()
# Out:
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# dtype: int64

# %% [markdown]
# Description:
# By Analysising the Data information and Checking the Dataset describing that the Dataset has "NO NULL VALUES".

# %%
#Distribution of Target variable
plt.figure(figsize =(12,6))
sns.distplot(Student_Data['G3'])
plt.title("Distribution of G3- Final Grade")
# Out:
# Text(0.5, 1.0, 'Distribution of G3- Final Grade')

# %% [markdown]
# # Data Analysis

# %%
Student_Data.shape
# Out:
# (395, 33)

# %%
Student_Data.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
Student_Data.groupby(['school'])['G3'].agg(['sum','mean','count']).reset_index()
# Out:
#   school   sum       mean  count
# 0     GP  3661  10.489971    349
# 1     MS   453   9.847826     46

# %%
# Get the number of distinct (unique) values in each column
Student_Data['school'].unique()
# Out:
# array(['GP', 'MS'], dtype=object)

# %%
Student_Data.groupby(['sex'])['G3'].agg(['sum','mean','count']).reset_index()
# Out:
#   sex   sum       mean  count
# 0   F  2073   9.966346    208
# 1   M  2041  10.914439    187

# %%
# Get the number of distinct (unique) values in each column
Student_Data['sex'].unique()
# Out:
# array(['F', 'M'], dtype=object)

# %%
Student_Data.groupby(['age'])['G3'].agg(['sum','count']).reset_index().head()
# Out:
#    age   sum  count
# 0   15   923     82
# 1   16  1147    104
# 2   17  1007     98
# 3   18   783     82
# 4   19   197     24

# %%
#Student_Data['age'].sum()

# %%
# Get the number of distinct (unique) values in each column
Student_Data['age'].unique()
# Out:
# array([18, 17, 15, 16, 19, 22, 20, 21], dtype=int64)

# %%
Student_Data.groupby(['address'])['G3'].agg(['sum','count']).reset_index()
# Out:
#   address   sum  count
# 0       R   837     88
# 1       U  3277    307

# %%
# Get the number of distinct (unique) values in each column
Student_Data['address'].unique()
# Out:
# array(['U', 'R'], dtype=object)

# %%
Student_Data.groupby(['famsize'])['G3'].agg(['sum','count']).reset_index()
# Out:
#   famsize   sum  count
# 0     GT3  2860    281
# 1     LE3  1254    114

# %%
# Get the number of distinct (unique) values in each column
Student_Data['famsize'].unique()
# Out:
# array(['GT3', 'LE3'], dtype=object)

# %%
Student_Data.groupby(['Pstatus'])['G3'].agg(['sum','count']).reset_index()
# Out:
#   Pstatus   sum  count
# 0       A   459     41
# 1       T  3655    354

# %%
# Get the number of distinct (unique) values in each column
Student_Data['Pstatus'].unique()
# Out:
# array(['A', 'T'], dtype=object)

# %%
Student_Data.groupby(['Medu'])['G3'].agg(['sum','mean','count']).reset_index()
# Out:
#    Medu   sum       mean  count
# 0     0    39  13.000000      3
# 1     1   512   8.677966     59
# 2     2  1002   9.728155    103
# 3     3  1020  10.303030     99
# 4     4  1541  11.763359    131

# %%
Student_Data['Medu'].sum()
# Out:
# 1086

# %%
# Get the number of distinct (unique) values in each column
Student_Data['Medu'].unique()
# Out:
# array([4, 1, 3, 2, 0], dtype=int64)

# %%
Student_Data.groupby(['Fedu'])['G3'].agg(['sum','mean','count']).reset_index()
# Out:
#    Fedu   sum       mean  count
# 0     0    26  13.000000      2
# 1     1   751   9.158537     82
# 2     2  1180  10.260870    115
# 3     3  1066  10.660000    100
# 4     4  1091  11.364583     96

# %%
Student_Data['Fedu'].sum()
# Out:
# 996

# %%
# Get the number of distinct (unique) values in each column
Student_Data['Fedu'].unique()
# Out:
# array([4, 1, 2, 3, 0], dtype=int64)

# %%
Student_Data.groupby(['Mjob'])['G3'].agg(['sum','mean','count']).reset_index()
# Out:
#        Mjob   sum       mean  count
# 0   at_home   540   9.152542     59
# 1    health   413  12.147059     34
# 2     other  1385   9.822695    141
# 3  services  1135  11.019417    103
# 4   teacher   641  11.051724     58

# %%
# Get the number of distinct (unique) values in each column
Student_Data['Mjob'].unique()
# Out:
# array(['at_home', 'health', 'other', 'services', 'teacher'], dtype=object)

# %%
Student_Data.groupby(['Fjob'])['G3'].agg(['sum','mean','count']).reset_index()
# Out:
#        Fjob   sum       mean  count
# 0   at_home   203  10.150000     20
# 1    health   209  11.611111     18
# 2     other  2212  10.193548    217
# 3  services  1143  10.297297    111
# 4   teacher   347  11.965517     29

# %%
# Get the number of distinct (unique) values in each column
Student_Data['Fjob'].unique()
# Out:
# array(['teacher', 'other', 'services', 'health', 'at_home'], dtype=object)

# %%
Student_Data.groupby(['reason'])['G3'].agg(['sum','mean','count']).reset_index()
# Out:
#        reason   sum       mean  count
# 0      course  1424   9.820690    145
# 1        home  1118  10.256881    109
# 2       other   402  11.166667     36
# 3  reputation  1170  11.142857    105

# %%
# Get the number of distinct (unique) values in each column
Student_Data['reason'].unique()
# Out:
# array(['course', 'other', 'home', 'reputation'], dtype=object)

# %%
Student_Data.groupby(['guardian'])['G3'].agg(['sum','mean','count']).reset_index()
# Out:
#   guardian   sum       mean  count
# 0   father   962  10.688889     90
# 1   mother  2862  10.483516    273
# 2    other   290   9.062500     32

# %%
# Get the number of distinct (unique) values in each column
Student_Data['guardian'].unique()
# Out:
# array(['mother', 'father', 'other'], dtype=object)

# %%
Student_Data.groupby(['traveltime'])['G3'].agg(['sum','mean','count']).reset_index()
# Out:
#    traveltime   sum       mean  count
# 0           1  2771  10.782101    257
# 1           2  1060   9.906542    107
# 2           3   213   9.260870     23
# 3           4    70   8.750000      8

# %%
Student_Data['traveltime'].sum()
# Out:
# 572

# %%
# Get the number of distinct (unique) values in each column
Student_Data['traveltime'].unique()
# Out:
# array([2, 1, 3, 4], dtype=int64)

# %%
Student_Data.groupby(['studytime'])['G3'].agg(['sum','mean','count']).reset_index()
# Out:
#    studytime   sum       mean  count
# 0          1  1055  10.047619    105
# 1          2  2014  10.171717    198
# 2          3   741  11.400000     65
# 3          4   304  11.259259     27

# %%
Student_Data['studytime'].sum()
# Out:
# 804

# %%
# Get the number of distinct (unique) values in each column
Student_Data['studytime'].unique()
# Out:
# array([2, 3, 1, 4], dtype=int64)

# %%
Student_Data.groupby(['failures'])['G3'].agg(['sum','mean','count']).reset_index()
# Out:
#    failures   sum       mean  count
# 0         0  3511  11.253205    312
# 1         1   406   8.120000     50
# 2         2   106   6.235294     17
# 3         3    91   5.687500     16

# %%
Student_Data['failures'].sum()
# Out:
# 132

# %%
# Get the number of distinct (unique) values in each column
Student_Data['failures'].unique()
# Out:
# array([0, 3, 2, 1], dtype=int64)

# %%
Student_Data.groupby(['schoolsup'])['G3'].agg(['sum','mean','count']).reset_index()
# Out:
#   schoolsup   sum       mean  count
# 0        no  3633  10.561047    344
# 1       yes   481   9.431373     51

# %%
# Get the number of distinct (unique) values in each column
Student_Data['schoolsup'].unique()
# Out:
# array(['yes', 'no'], dtype=object)

# %%
Student_Data.groupby(['famsup'])['G3'].agg(['sum','mean','count']).reset_index()
# Out:
#   famsup   sum       mean  count
# 0     no  1628  10.640523    153
# 1    yes  2486  10.272727    242

# %%
# Get the number of distinct (unique) values in each column
Student_Data['famsup'].unique()
# Out:
# array(['no', 'yes'], dtype=object)

# %%
Student_Data.groupby(['paid'])['G3'].agg(['sum','mean','count']).reset_index()
# Out:
#   paid   sum       mean  count
# 0   no  2137   9.985981    214
# 1  yes  1977  10.922652    181

# %%
Student_Data.groupby(['activities'])['G3'].agg(['sum','mean','count']).reset_index()
# Out:
#   activities   sum       mean  count
# 0         no  2006  10.340206    194
# 1        yes  2108  10.487562    201

# %%
Student_Data.groupby(['nursery'])['G3'].agg(['sum','mean','count']).reset_index()
# Out:
#   nursery   sum       mean  count
# 0      no   806   9.950617     81
# 1     yes  3308  10.535032    314

# %%
Student_Data.groupby(['higher'])['G3'].agg(['sum','mean','count']).reset_index()
# Out:
#   higher   sum    mean  count
# 0     no   136   6.800     20
# 1    yes  3978  10.608    375

# %%
Student_Data.groupby(['internet'])['G3'].agg(['sum','mean','count']).reset_index()
# Out:
#   internet   sum       mean  count
# 0       no   621   9.409091     66
# 1      yes  3493  10.617021    329

# %%
Student_Data.groupby(['romantic'])['G3'].agg(['sum','mean','count']).reset_index()
# Out:
#   romantic   sum       mean  count
# 0       no  2850  10.836502    263
# 1      yes  1264   9.575758    132

# %%
Student_Data.groupby(['famrel'])['G3'].agg(['sum','mean','count']).reset_index()
# Out:
#    famrel   sum       mean  count
# 0       1    85  10.625000      8
# 1       2   178   9.888889     18
# 2       3   683  10.044118     68
# 3       4  2020  10.358974    195
# 4       5  1148  10.830189    106

# %%
Student_Data['famrel'].sum()
# Out:
# 1558

# %%
# Get the number of distinct (unique) values in each column
Student_Data['famrel'].unique()
# Out:
# array([4, 5, 3, 1, 2], dtype=int64)

# %%
Student_Data.groupby(['freetime'])['G3'].agg(['sum','mean','count']).reset_index()
# Out:
#    freetime   sum       mean  count
# 0         1   187   9.842105     19
# 1         2   740  11.562500     64
# 2         3  1536   9.783439    157
# 3         4  1199  10.426087    115
# 4         5   452  11.300000     40

# %%
Student_Data['freetime'].sum()
# Out:
# 1278

# %%
# Get the number of distinct (unique) values in each column
Student_Data['freetime'].unique()
# Out:
# array([3, 2, 4, 1, 5], dtype=int64)

# %%
Student_Data.groupby(['goout'])['G3'].agg(['sum','mean','count']).reset_index()
# Out:
#    goout   sum       mean  count
# 0      1   227   9.869565     23
# 1      2  1153  11.194175    103
# 2      3  1425  10.961538    130
# 3      4   830   9.651163     86
# 4      5   479   9.037736     53

# %%
Student_Data['goout'].sum()
# Out:
# 1228

# %%
# Get the number of distinct (unique) values in each column
Student_Data['goout'].unique()
# Out:
# array([4, 3, 2, 1, 5], dtype=int64)

# %%
Student_Data.groupby(['Dalc'])['G3'].agg(['sum','mean','count']).reset_index()
# Out:
#    Dalc   sum       mean  count
# 0     1  2962  10.731884    276
# 1     2   694   9.253333     75
# 2     3   273  10.500000     26
# 3     4    89   9.888889      9
# 4     5    96  10.666667      9

# %%
Student_Data['Dalc'].sum()
# Out:
# 585

# %%
# Get the number of distinct (unique) values in each column
Student_Data['Dalc'].unique()
# Out:
# array([1, 2, 5, 3, 4], dtype=int64)

# %%
Student_Data.groupby(['Walc'])['G3'].agg(['sum','mean','count']).reset_index()
# Out:
#    Walc   sum       mean  count
# 0     1  1621  10.735099    151
# 1     2   857  10.082353     85
# 2     3   858  10.725000     80
# 3     4   494   9.686275     51
# 4     5   284  10.142857     28

# %%
Student_Data['Walc'].sum()
# Out:
# 905

# %%
# Get the number of distinct (unique) values in each column
Student_Data['Walc'].unique()
# Out:
# array([1, 3, 2, 4, 5], dtype=int64)

# %%
Student_Data.groupby(['health'])['G3'].agg(['sum','mean','count']).reset_index()
# Out:
#    health   sum       mean  count
# 0       1   558  11.872340     47
# 1       2   460  10.222222     45
# 2       3   911  10.010989     91
# 3       4   667  10.106061     66
# 4       5  1518  10.397260    146

# %%
Student_Data['health'].sum()
# Out:
# 1404

# %%
# Get the number of distinct (unique) values in each column
Student_Data['health'].unique()
# Out:
# array([3, 5, 1, 2, 4], dtype=int64)

# %%
Student_Data.groupby(['absences'])['G3'].agg(['sum','mean','count']).reset_index()
# Out:
#     absences  sum       mean  count
# 0          0  971   8.443478    115
# 1          1   39  13.000000      3
# 2          2  774  11.907692     65
# 3          3   92  11.500000      8
# 4          4  598  11.283019     53
# 5          5   58  11.600000      5
# 6          6  365  11.774194     31
# 7          7   83  11.857143      7
# 8          8  233  10.590909     22
# 9          9   40  13.333333      3
# 10        10  191  11.235294     17
# 11        11   35  11.666667      3
# 12        12  129  10.750000     12
# 13        13   38  12.666667      3
# 14        14  112   9.333333     12
# 15        15   25   8.333333      3
# 16        16   69   9.857143      7
# 17        17   10  10.000000      1
# 18        18   42   8.400000      5
# 19        19   10  10.000000      1
# 20        20   46  11.500000      4
# 21        21   18  18.000000      1
# 22        22   24   8.000000      3
# 23        23   13  13.000000      1
# 24        24   18  18.000000      1
# ...

# %%
Student_Data['absences'].sum()
# Out:
# 2255

# %%
# Get the number of distinct (unique) values in each column
Student_Data['absences'].unique()
# Out:
# array([ 6,  4, 10,  2,  0, 16, 14,  7,  8, 25, 12, 54, 18, 26, 20, 56, 24,
#        28,  5, 13, 15, 22,  3, 21,  1, 75, 30, 19,  9, 11, 38, 40, 23, 17],
#       dtype=int64)

# %%
Student_Data.groupby(['G1'])['G3'].agg(['sum','mean','count']).reset_index()
# Out:
#     G1  sum       mean  count
# 0    3    5   5.000000      1
# 1    4    0   0.000000      1
# 2    5   31   4.428571      7
# 3    6  101   4.208333     24
# 4    7  207   5.594595     37
# 5    8  333   8.121951     41
# 6    9  250   8.064516     31
# 7   10  472   9.254902     51
# 8   11  419  10.743590     39
# 9   12  419  11.971429     35
# 10  13  421  12.757576     33
# 11  14  414  13.800000     30
# 12  15  352  14.666667     24
# 13  16  353  16.045455     22
# 14  17  135  16.875000      8
# 15  18  145  18.125000      8
# 16  19   57  19.000000      3

# %%
Student_Data['G1'].sum()
# Out:
# 4309

# %%
# Get the number of distinct (unique) values in each column
Student_Data['G1'].unique()
# Out:
# array([ 5,  7, 15,  6, 12, 16, 14, 10, 13,  8, 11,  9, 17, 19, 18,  4,  3],
#       dtype=int64)

# %%
Student_Data.groupby(['G2'])['G3'].agg(['sum','mean','count']).reset_index()
# Out:
#     G2  sum       mean  count
# 0    0    0   0.000000     13
# 1    4    0   0.000000      1
# 2    5   49   3.266667     15
# 3    6   67   4.785714     14
# 4    7  124   5.904762     21
# 5    8  238   7.437500     32
# 6    9  411   8.220000     50
# 7   10  450   9.782609     46
# 8   11  383  10.942857     35
# 9   12  489  11.926829     41
# 10  13  485  13.108108     37
# 11  14  325  14.130435     23
# 12  15  520  15.294118     34
# 13  16  209  16.076923     13
# 14  17   87  17.400000      5
# 15  18  219  18.250000     12
# 16  19   58  19.333333      3

# %%
Student_Data['G2'].sum()
# Out:
# 4232

# %%
# Get the number of distinct (unique) values in each column
Student_Data['G2'].unique()
# Out:
# array([ 6,  5,  8, 14, 10, 15, 12, 18, 16, 13,  9, 11,  7, 19, 17,  4,  0],
#       dtype=int64)

# %%
Student_Data.groupby(['G3'])['G3'].agg(['sum','mean','count']).reset_index()
# Out:
#     G3  sum  mean  count
# 0    0    0   0.0     38
# 1    4    4   4.0      1
# 2    5   35   5.0      7
# 3    6   90   6.0     15
# 4    7   63   7.0      9
# 5    8  256   8.0     32
# 6    9  252   9.0     28
# 7   10  560  10.0     56
# 8   11  517  11.0     47
# 9   12  372  12.0     31
# 10  13  403  13.0     31
# 11  14  378  14.0     27
# 12  15  495  15.0     33
# 13  16  256  16.0     16
# 14  17  102  17.0      6
# 15  18  216  18.0     12
# 16  19   95  19.0      5
# 17  20   20  20.0      1

# %%
Student_Data['G3'].sum()
# Out:
# 4114

# %%
# Get the number of distinct (unique) values in each column
Student_Data['G3'].unique()
# Out:
# array([ 6, 10, 15, 11, 19,  9, 12, 14, 16,  5,  8, 17, 18, 13, 20,  7,  0,
#         4], dtype=int64)

# %% [markdown]
# # Splitting the dataset into Numerical and Categorical Features

# %% [markdown]
# ## Numerical features

# %%
Numerical_features = Student_Data.select_dtypes(include = ['integer']).columns.tolist()
print("No of Numerical Features:",len(Numerical_features))
Student_Data[Numerical_features].head()
# Out:
# No of Numerical Features: 16
#    age  Medu  Fedu  traveltime  studytime  failures  famrel  freetime  goout  \
# 0   18     4     4           2          2         0       4         3      4
# 1   17     1     1           1          2         0       5         3      3
# 2   15     1     1           1          2         3       4         3      2
# 3   15     4     2           1          3         0       3         2      2
# 4   16     3     3           1          2         0       4         3      2
#
#    Dalc  Walc  health  absences  G1  G2  G3
# 0     1     1       3         6   5   6   6
# 1     1     1       3         4   5   5   6
# 2     2     3       3        10   7   8  10
# 3     1     1       5         2  15  14  15
# 4     1     2       5         4   6  10  10

# %%
Student_Data[Numerical_features].columns.tolist()
# Out:
# ['age',
#  'Medu',
#  'Fedu',
#  'traveltime',
#  'studytime',
#  'failures',
#  'famrel',
#  'freetime',
#  'goout',
#  'Dalc',
#  'Walc',
#  'health',
#  'absences',
#  'G1',
#  'G2',
#  'G3']

# %% [markdown]
# ## Categorical Features

# %%
Categorical_features = Student_Data.select_dtypes(include = ['object']).columns.tolist()
print("No of Categorical Features:", len(Categorical_features))
Student_Data[Categorical_features].head()
# Out:
# No of Categorical Features: 17
#   school sex address famsize Pstatus     Mjob      Fjob  reason guardian  \
# 0     GP   F       U     GT3       A  at_home   teacher  course   mother
# 1     GP   F       U     GT3       T  at_home     other  course   father
# 2     GP   F       U     LE3       T  at_home     other   other   mother
# 3     GP   F       U     GT3       T   health  services    home   mother
# 4     GP   F       U     GT3       T    other     other    home   father
#
#   schoolsup famsup paid activities nursery higher internet romantic
# 0       yes     no   no         no     yes    yes       no       no
# 1        no    yes   no         no      no    yes      yes       no
# 2       yes     no  yes         no     yes    yes      yes       no
# 3        no    yes  yes        yes     yes    yes      yes      yes
# 4        no    yes  yes         no     yes    yes       no       no

# %%
Student_Data[Categorical_features].columns.tolist()
# Out:
# ['school',
#  'sex',
#  'address',
#  'famsize',
#  'Pstatus',
#  'Mjob',
#  'Fjob',
#  'reason',
#  'guardian',
#  'schoolsup',
#  'famsup',
#  'paid',
#  'activities',
#  'nursery',
#  'higher',
#  'internet',
#  'romantic']

# %% [markdown]
# # Features Visualization

# %% [markdown]
# ## Numerical Features visualization

# %%
plt.figure(figsize=(12,6))
sns.barplot(x = 'G3' , y = 'age', data = Student_Data, palette = 'viridis')
plt.title("Relationship between Age and Final Grade from Student Performance")
# Out:
# Text(0.5, 1.0, 'Relationship between Age and Final Grade from Student Performance')

# %%
plt.figure(figsize=(12,6))
sns.barplot(x = 'G3' , y = 'Medu', data = Student_Data, palette = 'viridis')
plt.title("Relationship between Medu and Final Grade from Student Performance")
# Out:
# Text(0.5, 1.0, 'Relationship between Medu and Final Grade from Student Performance')

# %%
plt.figure(figsize=(12,6))
sns.barplot(x = 'G3' , y = 'Fedu', data = Student_Data, palette = 'viridis')
plt.title("Relationship between Fedu and Final Grade from Student Performance")
# Out:
# Text(0.5, 1.0, 'Relationship between Fedu and Final Grade from Student Performance')

# %%
plt.figure(figsize=(12,6))
sns.barplot(x = 'G3' , y = 'traveltime', data = Student_Data, palette = 'viridis')
plt.title("Relationship between traveltime and Final Grade from Student Performance")
# Out:
# Text(0.5, 1.0, 'Relationship between traveltime and Final Grade from Student Performance')

# %%
plt.figure(figsize=(12,6))
sns.barplot(x = 'G3' , y = 'studytime', data = Student_Data, palette = 'viridis')
plt.title("Relationship between studytime and Final Grade from Student Performance")
# Out:
# Text(0.5, 1.0, 'Relationship between studytime and Final Grade from Student Performance')

# %%
plt.figure(figsize=(12,6))
sns.barplot(x = 'G3' , y = 'failures', data = Student_Data, palette = 'viridis')
plt.title("Relationship between failures and Final Grade from Student Performance")
# Out:
# Text(0.5, 1.0, 'Relationship between failures and Final Grade from Student Performance')

# %%
plt.figure(figsize=(12,6))
sns.barplot(x = 'G3' , y = 'famrel', data = Student_Data, palette = 'viridis')
plt.title("Relationship between famrel and Final Grade from Student Performance")
# Out:
# Text(0.5, 1.0, 'Relationship between famrel and Final Grade from Student Performance')

# %%
plt.figure(figsize=(12,6))
sns.barplot(x = 'G3' , y = 'freetime', data = Student_Data, palette = 'viridis')
plt.title("Relationship between freetime and Final Grade from Student Performance")
# Out:
# Text(0.5, 1.0, 'Relationship between freetime and Final Grade from Student Performance')

# %%
plt.figure(figsize=(12,6))
sns.barplot(x = 'G3' , y = 'goout', data = Student_Data, palette = 'viridis')
plt.title("Relationship between goout and Final Grade from Student Performance")
# Out:
# Text(0.5, 1.0, 'Relationship between goout and Final Grade from Student Performance')

# %%
plt.figure(figsize=(12,6))
sns.barplot(x = 'G3' , y = 'Dalc', data = Student_Data, palette = 'viridis')
plt.title("Relationship between Dalc and Final Grade from Student Performance")
# Out:
# Text(0.5, 1.0, 'Relationship between Dalc and Final Grade from Student Performance')

# %%
plt.figure(figsize=(12,6))
sns.barplot(x = 'G3' , y = 'Walc', data = Student_Data, palette = 'viridis')
plt.title("Relationship between Walc and Final Grade from Student Performance")
# Out:
# Text(0.5, 1.0, 'Relationship between Walc and Final Grade from Student Performance')

# %%
plt.figure(figsize=(12,6))
sns.barplot(x = 'G3' , y = 'health', data = Student_Data, palette = 'viridis')
plt.title("Relationship between health and Final Grade from Student Performance")
# Out:
# Text(0.5, 1.0, 'Relationship between health and Final Grade from Student Performance')

# %%
plt.figure(figsize=(12,6))
sns.barplot(x = 'G3' , y = 'absences', data = Student_Data, palette = 'viridis')
plt.title("Relationship between absences and Final Grade from Student Performance")
# Out:
# Text(0.5, 1.0, 'Relationship between absences and Final Grade from Student Performance')

# %%
plt.figure(figsize=(12,6))
sns.barplot(x = 'G3' , y = 'G1', data = Student_Data, palette = 'viridis')
plt.title("Relationship between Age and Final Grade from Student Performance")
# Out:
# Text(0.5, 1.0, 'Relationship between Age and Final Grade from Student Performance')

# %%
plt.figure(figsize=(12,6))
sns.barplot(x = 'G3' , y = 'G2', data = Student_Data, palette = 'viridis')
plt.title("Relationship between Age and Final Grade from Student Performance")
# Out:
# Text(0.5, 1.0, 'Relationship between Age and Final Grade from Student Performance')

# %% [markdown]
# ## Categorical Features Visualization

# %%
plt.figure(figsize=(7,6))
sns.barplot(x = 'school' , y = 'G3', data = Student_Data, palette = 'Blues')
plt.title("Relationship between school and Final Grade from Student Performance")
# Out:
# Text(0.5, 1.0, 'Relationship between school and Final Grade from Student Performance')

# %%
plt.figure(figsize=(7,6))
sns.barplot(x = 'sex' , y = 'G3', data = Student_Data, palette = 'Blues')
plt.title("Relationship between sex and Final Grade from Student Performance")
# Out:
# Text(0.5, 1.0, 'Relationship between sex and Final Grade from Student Performance')

# %%
plt.figure(figsize=(7,6))
sns.barplot(x = 'address' , y = 'G3', data = Student_Data, palette = 'Blues')
plt.title("Relationship between address and Final Grade from Student Performance")
# Out:
# Text(0.5, 1.0, 'Relationship between address and Final Grade from Student Performance')

# %%
plt.figure(figsize=(7,6))
sns.barplot(y = 'G3' , x = 'famsize', data = Student_Data, palette = 'Blues')
plt.title("Relationship between famsize and Final Grade from Student Performance")
# Out:
# Text(0.5, 1.0, 'Relationship between famsize and Final Grade from Student Performance')

# %%
plt.figure(figsize=(7,6))
sns.barplot(y = 'G3' , x = 'Pstatus', data = Student_Data, palette = 'Blues')
plt.title("Relationship between Pstatus and Final Grade from Student Performance")
# Out:
# Text(0.5, 1.0, 'Relationship between Pstatus and Final Grade from Student Performance')

# %%
plt.figure(figsize=(7,6))
sns.barplot(y = 'G3' , x = 'Mjob', data = Student_Data, palette = 'Blues')
plt.title("Relationship between Mjob and Final Grade from Student Performance")
# Out:
# Text(0.5, 1.0, 'Relationship between Mjob and Final Grade from Student Performance')

# %%
plt.figure(figsize=(7,6))
sns.barplot(y = 'G3' ,x = 'Fjob', data = Student_Data, palette = 'Blues')
plt.title("Relationship between Fjob and Final Grade from Student Performance")
# Out:
# Text(0.5, 1.0, 'Relationship between Fjob and Final Grade from Student Performance')

# %%
plt.figure(figsize=(7,6))
sns.barplot(y = 'G3' , x = 'reason', data = Student_Data, palette = 'Blues')
plt.title("Relationship between reason and Final Grade from Student Performance")
# Out:
# Text(0.5, 1.0, 'Relationship between reason and Final Grade from Student Performance')

# %%
plt.figure(figsize=(7,6))
sns.barplot(y = 'G3' , x = 'guardian', data = Student_Data, palette = 'Blues')
plt.title("Relationship between guardian and Final Grade from Student Performance")
# Out:
# Text(0.5, 1.0, 'Relationship between guardian and Final Grade from Student Performance')

# %%
plt.figure(figsize=(7,6))
sns.barplot(y = 'G3' , x = 'schoolsup', data = Student_Data, palette = 'Blues')
plt.title("Relationship between schoolsup and Final Grade from Student Performance")
# Out:
# Text(0.5, 1.0, 'Relationship between schoolsup and Final Grade from Student Performance')

# %%
plt.figure(figsize=(7,6))
sns.barplot(y = 'G3' , x = 'famsup', data = Student_Data, palette = 'Blues')
plt.title("Relationship between famsup and Final Grade from Student Performance")
# Out:
# Text(0.5, 1.0, 'Relationship between famsup and Final Grade from Student Performance')

# %%
plt.figure(figsize=(7,6))
sns.barplot(y = 'G3' , x = 'paid', data = Student_Data, palette = 'Blues')
plt.title("Relationship between paid and Final Grade from Student Performance")
# Out:
# Text(0.5, 1.0, 'Relationship between paid and Final Grade from Student Performance')

# %%
plt.figure(figsize=(7,6))
sns.barplot(y = 'G3' , x = 'activities', data = Student_Data, palette = 'Blues')
plt.title("Relationship between activities and Final Grade from Student Performance")
# Out:
# Text(0.5, 1.0, 'Relationship between activities and Final Grade from Student Performance')

# %%
plt.figure(figsize=(7,6))
sns.barplot(y = 'G3' , x = 'nursery', data = Student_Data, palette = 'Blues')
plt.title("Relationship between nursery and Final Grade from Student Performance")
# Out:
# Text(0.5, 1.0, 'Relationship between nursery and Final Grade from Student Performance')

# %%
plt.figure(figsize=(7,6))
sns.barplot(y = 'G3' , x = 'higher', data = Student_Data, palette = 'Blues')
plt.title("Relationship between higher and Final Grade from Student Performance")
# Out:
# Text(0.5, 1.0, 'Relationship between higher and Final Grade from Student Performance')

# %%
plt.figure(figsize=(7,6))
sns.barplot(y = 'G3' , x = 'internet', data = Student_Data, palette = 'Blues')
plt.title("Relationship between internet and Final Grade from Student Performance")
# Out:
# Text(0.5, 1.0, 'Relationship between internet and Final Grade from Student Performance')

# %%
plt.figure(figsize=(7,6))
sns.barplot(y = 'G3' , x = 'romantic', data = Student_Data, palette = 'Blues')
plt.title("Relationship between romantic and Final Grade from Student Performance")
# Out:
# Text(0.5, 1.0, 'Relationship between romantic and Final Grade from Student Performance')

# %%
plt.figure(figsize=(12,6))
sns.barplot(x = 'G3' , y = 'age', data = Student_Data, palette = 'Blues')
plt.title("Relationship between Age and Final Grade from Student Performance")
# Out:
# Text(0.5, 1.0, 'Relationship between Age and Final Grade from Student Performance')

# %% [markdown]
# # Outliers Detection

# %%
plt.figure(figsize=(12,6))
sns.boxplot(y = 'age' , data = Student_Data, palette = 'Set3')
plt.title("Outliers detection for G3 from Student Performance")
# Out:
# Text(0.5, 1.0, 'Outliers detection for G3 from Student Performance')

# %%
plt.figure(figsize=(12,6))
sns.boxplot(y = 'Medu' , data = Student_Data, palette = 'deep')
plt.title("Outliers detection for Medu from Student Performance")
# Out:
# Text(0.5, 1.0, 'Outliers detection for Medu from Student Performance')

# %%
plt.figure(figsize=(12,6))
sns.boxplot(y = 'Fedu' , data = Student_Data, palette = 'muted')
plt.title("Outliers detection for Fedu from Student Performance")
# Out:
# Text(0.5, 1.0, 'Outliers detection for Fedu from Student Performance')

# %%
plt.figure(figsize=(12,6))
sns.boxplot(y = 'traveltime' , data = Student_Data, palette = 'pastel')
plt.title("Outliers detection for traveltime from Student Performance")
# Out:
# Text(0.5, 1.0, 'Outliers detection for traveltime from Student Performance')

# %%
plt.figure(figsize=(12,6))
sns.boxplot(y = 'studytime' , data = Student_Data, palette = 'bright')
plt.title("Outliers detection for studytime from Student Performance")
# Out:
# Text(0.5, 1.0, 'Outliers detection for studytime from Student Performance')

# %%
plt.figure(figsize=(12,6))
sns.boxplot(y = 'failures' , data = Student_Data, palette = 'pastel')
plt.title("Outliers detection for failures from Student Performance")
# Out:
# Text(0.5, 1.0, 'Outliers detection for failures from Student Performance')

# %%
plt.figure(figsize=(12,6))
sns.boxplot(y = 'famrel' , data = Student_Data, palette = 'dark')
plt.title("Outliers detection for famrel from Student Performance")
# Out:
# Text(0.5, 1.0, 'Outliers detection for famrel from Student Performance')

# %%
plt.figure(figsize=(12,6))
sns.boxplot(y = 'freetime' , data = Student_Data, palette = 'colorblind')
plt.title("Outliers detection for freetime from Student Performance")
# Out:
# Text(0.5, 1.0, 'Outliers detection for freetime from Student Performance')

# %%
plt.figure(figsize=(12,6))
sns.boxplot(y = 'goout' , data = Student_Data, palette = 'Set1')
plt.title("Outliers detection for goout from Student Performance")
# Out:
# Text(0.5, 1.0, 'Outliers detection for goout from Student Performance')

# %%
plt.figure(figsize=(12,6))
sns.boxplot(y = 'Dalc' , data = Student_Data, palette = 'Set2')
plt.title("Outliers detection for Dalc from Student Performance")
# Out:
# Text(0.5, 1.0, 'Outliers detection for Dalc from Student Performance')

# %%
plt.figure(figsize=(12,6))
sns.boxplot(y = 'Walc' , data = Student_Data, palette = 'Set3')
plt.title("Outliers detection for Walc from Student Performance")
# Out:
# Text(0.5, 1.0, 'Outliers detection for Walc from Student Performance')

# %%
plt.figure(figsize=(12,6))
sns.boxplot(y = 'health' , data = Student_Data, palette = 'Paired')
plt.title("Outliers detection for health from Student Performance")
# Out:
# Text(0.5, 1.0, 'Outliers detection for health from Student Performance')

# %%
plt.figure(figsize=(12,6))
sns.boxplot(y = 'absences' , data = Student_Data, palette = 'coolwarm')
plt.title("Outliers detection for absences from Student Performance")
# Out:
# Text(0.5, 1.0, 'Outliers detection for absences from Student Performance')

# %%
plt.figure(figsize=(12,6))
sns.boxplot(y = 'G1' , data = Student_Data, palette = 'bright')
plt.title("Outliers detection for G1 from Student Performance")
# Out:
# Text(0.5, 1.0, 'Outliers detection for G1 from Student Performance')

# %%
plt.figure(figsize=(12,6))
sns.boxplot(y = 'G2' , data = Student_Data, palette = 'deep')
plt.title("Outliers detection for G2 from Student Performance")
# Out:
# Text(0.5, 1.0, 'Outliers detection for G2 from Student Performance')

# %%
plt.figure(figsize=(12,6))
sns.boxplot(y = 'G3' , data = Student_Data, palette = 'coolwarm')
plt.title("Outliers detection for G3 from Student Performance")
# Out:
# Text(0.5, 1.0, 'Outliers detection for G3 from Student Performance')
